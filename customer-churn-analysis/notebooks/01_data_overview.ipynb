# %% [markdown]
# ## Data Overview

# %%
import pandas as pd

# %%
## Load data from csv
data = pd.read_csv("../data/raw/Telco-Customer-Churn.csv")

# %%
## Data shape: How big the data is?
data.shape
# Out:
# (7043, 21)

# %%
## How does the data look like?
data.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6246  7054-DMVAS    Male              0      No         No      54
# 6328  4701-LKOZD  Female              0      No         No      70
# 6907  1041-RXHRA  Female              0      No         No      41
# 3046  8715-KKTFG  Female              0     Yes         No      61
# 4046  0440-QEXBZ  Female              0      No         No      44
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 6246          Yes            No             DSL            Yes  ...
# 6328          Yes           Yes             DSL            Yes  ...
# 6907          Yes            No     Fiber optic             No  ...
# 3046          Yes           Yes     Fiber optic             No  ...
# 4046          Yes           Yes             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
## Basic Information: type of cols, missing vlaues, etc
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7040 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# #### Comment:
# Column `TotalCharges` is of object type but should be numeric. There are some empty strings that need to be handled.

# %%
## Check for missing values
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          3
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      5
# TotalCharges        3
# Churn               0
# dtype: int64

# %% [markdown]
# #### Comment:
# There are some columns that contains missing values.

# %%
## Check for duplicate values
data.duplicated().sum()
# Out:
# np.int64(2)

# %% [markdown]
# #### Comment:
# There are two duplicate rows in the dataset.

# %%
## Basic descriptive stats: How data looks mathematically?
data.describe(include=['int', 'float'])
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7038.000000
# mean        0.162431    32.359080       64.745027
# std         0.368872    24.556385       30.079478
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000
